# %%
import os
import subprocess
import sys
import time

import matplotlib.pyplot as plt
__file__ = os.path.abspath('')
module_path = __file__ + ""
sys.path.append(os.path.abspath(''))

try:
    from BindWrapper import *
    print("Library imported")
except:
    print("Something went wrong during import")
    print("__file__ : " + __file__)
    print("sys.path: " + str(sys.path))
# Out:
# Library imported
# Library imported

# %%
b = BindWrapper()

# %%
#Set parameters of model
b.filename = "figury_biale.png"
b.size = 30
b.genes_count = 100
b.max_generation = 2000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 0

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=10,number_of_steps=5,step_size=20,number_of_tries=2)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
#Set parameters of model
b.filename = "figury_biale.png"
b.size = 30
b.genes_count = 500
b.max_generation = 100000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 300

# %%
multiple_genes_data = b.test_multiple_times("genes_count",min_value=100,number_of_steps=6,step_size=500,number_of_tries=5)
generations = multiple_genes_data.pop("gen")

# %%
for key, value in multiple_genes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple numbers of genes for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
#Set parameters of model
b.filename = "figury_czarne.png"
b.size = 30
b.genes_count = 100
b.max_generation = 2000
b.has_window = False
b.save_result_image = False

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=10,number_of_steps=5,step_size=20,number_of_tries=2)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
multiple_genes_data = b.test_multiple_times("genes_count",min_value=100,number_of_steps=6,step_size=500,number_of_tries=2)
generations = multiple_genes_data.pop("gen")

# %%
for key, value in multiple_genes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple numbers of genes for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
#Set parameters of model
b.filename = "papuga.png"
b.size = 30
b.genes_count = 1000
b.max_generation = 2000
b.has_window = False
b.save_result_image = False

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=30,number_of_steps=0,step_size=1,number_of_tries=20)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
#Set parameters of model
b.filename = "figury_biale.png"
b.size = 30
b.genes_count = 1000
b.max_generation = 200000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 120

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=30,number_of_steps=0,step_size=1,number_of_tries=20)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()
# Out:
#   File "<ipython-input-6-ebf14c65cb2b>", line 3
#     plt.legend(title="Size")
#     ^
# SyntaxError: invalid syntax

# %%
#Set parameters of model
b.filename = "figury_czarne.png"
b.size = 30
b.genes_count = 1000
b.max_generation = 200000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 120

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=30,number_of_steps=0,step_size=1,number_of_tries=20)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
b.filename = "figury_czarne.png"
b.size = 30
b.genes_count = 100
b.max_generation = 20000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 120

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=10,number_of_steps=5,step_size=20,number_of_tries=5)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
b.filename = "figury_biale.png"
b.size = 30
b.genes_count = 100
b.max_generation = 200000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 120

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=10,number_of_steps=5,step_size=20,number_of_tries=5)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value)), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
b.filename = "figury_czarne.png"
b.size = 30
b.genes_count = 100
b.max_generation = 100000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 120

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=10,number_of_steps=5,step_size=20,number_of_tries=5)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value)), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()

# %%
b.filename = "papuga.png"
b.size = 30
b.genes_count = 100
b.max_generation = 100000
b.has_window = False
b.save_result_image = False
b.execution_timeout = 120

# %%
multiple_sizes_data = b.test_multiple_times("size",min_value=10,number_of_steps=5,step_size=20,number_of_tries=5)
generations = multiple_sizes_data.pop("gen")

# %%
for key, value in multiple_sizes_data.items():
    plt.plot(range(len(value)), value, label=str(key))
plt.legend(title="Size")
plt.title("Multiple sizes of population for " + b.filename)
plt.rcParams["figure.figsize"]=15,8

plt.show()
